# %% [markdown]
# ### Name : Awez Sheikh
# ### Batch : A2_32
# ### Practical 3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

imp=pd.read_csv("titanic.csv") #read file#skiprows to remove the data from up to down

import warnings
warnings.filterwarnings('ignore') # to ignore the warnings in the code

# %%
imp.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
imp.drop('Name',axis=1,inplace= True)

# %%
imp.drop('Ticket',axis=1,inplace= True)

# %%
imp.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
from sklearn.preprocessing import LabelEncoder

# %%
eSex= LabelEncoder()
imp['Sex_int']= eSex.fit_transform(imp['Sex'])  # male ==1 , female == 0

# %%
imp.head(10)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
# 5            6         0       3    male   NaN      0      0   8.4583   NaN
# 6            7         0       1    male  54.0      0      0  51.8625   E46
# 7            8         0       3    male   2.0      3      1  21.0750   NaN
# 8            9         1       3  female  27.0      0      2  11.1333   NaN
# 9           10         1       2  female  14.0      1      0  30.0708   NaN
#
#   Embarked  Sex_int
# 0        S        1
# 1        C        0
# 2        S        0
# 3        S        0
# 4        S        1
# ...

# %%
imp.drop('Sex',axis=1,inplace= True)

# %%
imp.drop('Fare',axis=1,inplace= True)

# %%
imp.head(10)
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch Cabin Embarked  Sex_int
# 0            1         0       3  22.0      1      0   NaN        S        1
# 1            2         1       1  38.0      1      0   C85        C        0
# 2            3         1       3  26.0      0      0   NaN        S        0
# 3            4         1       1  35.0      1      0  C123        S        0
# 4            5         0       3  35.0      0      0   NaN        S        1
# 5            6         0       3   NaN      0      0   NaN        Q        1
# 6            7         0       1  54.0      0      0   E46        S        1
# 7            8         0       3   2.0      3      1   NaN        S        1
# 8            9         1       3  27.0      0      2   NaN        S        0
# 9           10         1       2  14.0      1      0   NaN        C        0

# %%
imp.drop('Embarked',axis=1,inplace= True)
imp.drop('PassengerId',axis=1,inplace= True)
imp.drop(['Parch','SibSp'],axis=1,inplace= True)

# %%
imp.drop('Cabin',axis=1,inplace= True)

# %%
# method to change the string into int
# var.cloumn= var.column.map{{'str1':int,str2:int2.......}}

# %%
imp.head()
# Out:
#    Survived  Pclass   Age  Sex_int
# 0         0       3  22.0        1
# 1         1       1  38.0        0
# 2         1       3  26.0        0
# 3         1       1  35.0        0
# 4         0       3  35.0        1

# %%
imp.Age[:20]
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5      NaN
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17     NaN
# 18    31.0
# 19     NaN
# Name: Age, dtype: float64

# %%
x= imp.Age.mean()

# %%
imp.Age=imp.Age.fillna(x)

# %%
imp.head(20)
# Out:
#     Survived  Pclass        Age  Sex_int
# 0          0       3  22.000000        1
# 1          1       1  38.000000        0
# 2          1       3  26.000000        0
# 3          1       1  35.000000        0
# 4          0       3  35.000000        1
# 5          0       3  29.699118        1
# 6          0       1  54.000000        1
# 7          0       3   2.000000        1
# 8          1       3  27.000000        0
# 9          1       2  14.000000        0
# 10         1       3   4.000000        0
# 11         1       1  58.000000        0
# 12         0       3  20.000000        1
# 13         0       3  39.000000        1
# 14         0       3  14.000000        0
# 15         1       2  55.000000        0
# 16         0       3   2.000000        1
# 17         1       2  29.699118        1
# 18         0       3  31.000000        0
# 19         1       3  29.699118        0

# %%
imp.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Age         0
# Sex_int     0
# dtype: int64

# %%
target=imp['Survived']

# %%
data=imp.drop(['Survived'],axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score

# %%
imp.shape
# Out:
# (891, 4)

# %%
target.shape
# Out:
# (891,)

# %% [markdown]
# ## concept of cross validation

# %%
x_train,x_test,y_train,y_test=train_test_split(data,target,test_size =0.2)

# %%
len(x_train)
# Out:
# 712

# %%
from sklearn import tree

# %%
model =tree.DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x_test,y_test)
# Out:
# 0.7877094972067039

# %%
model.predict([[2,30.0,2]])
# Out:
# array([0], dtype=int64)

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(100,100))
plot_tree(model,filled= True,feature_names=['Pclass','Age','Sex_int'],class_names=['0','1'])
plt.show()
